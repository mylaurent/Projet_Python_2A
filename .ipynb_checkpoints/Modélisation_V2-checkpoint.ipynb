# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
import os 
import pandas as pd
import urllib
import bs4
import re
import copy
import collections as co
import plotly
import plotly.graph_objects as go

# %%
AS_N = pd.read_csv(r'C:\Users\User\Documents\GitHub\Projet_Python_2A\AS_N.csv')

# %%
AS_N.head()
# Out:
#    Unnamed: 0      Series Title  Year Released Content Rating  IMDB Rating  \
# 0           0      Breaking Bad           2008            18+          9.5
# 1           3   Stranger Things           2016            16+          8.8
# 2           5              Dark           2017            16+          8.8
# 3           7          Sherlock           2010            16+          9.1
# 4          14  Better Call Saul           2015            18+          8.7
#
#    R Rating                     Genre  \
# 0       100               Crime,Drama
# 1        96             Drama,Fantasy
# 2        95               Crime,Drama
# 3        94  Action & Adventure,Crime
# 4        92              Comedy,Crime
#
#                                          Description  No of Seasons  \
# 0  When Walter White, a New Mexico chemistry teac...              5
# 1  When a young boy vanishes, a small town uncove...              3
# 2  A missing child causes four families to help e...              3
# 3  A modern update finds the famous sleuth and hi...              4
# 4  Six years before Saul Goodman meets Walter Whi...              5
#
#   Streaming Platform  Top IMDB
# 0            Netflix         1
# 1            Netflix         1
# 2            Netflix         1
# 3            Netflix         1
# 4            Netflix         1

# %%
AS_N.dtypes
# Out:
# Unnamed: 0              int64
# Series Title           object
# Year Released           int64
# Content Rating         object
# IMDB Rating           float64
# R Rating                int64
# Genre                  object
# Description            object
# No of Seasons           int64
# Streaming Platform     object
# Top IMDB                int64
# dtype: object

# %%
AS_N[['No of Seasons']].isna().sum()
AS_N[['Top IMDB']].isna().sum()
# Out:
# Top IMDB    0
# dtype: int64

# %%
#AS_N['R Rating'] = df_AS_N['R Rating'].div(10)

# %%
# Matrice de corrélation
def plotCorrelationMatrix(df, graphWidth):
#    filename = df.dataframeName
    df = df.dropna('rows' in ['Year released', 'IMDB Rating', 'R Rating', 'Score',]) # drop rows with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = sns.heatmap(df.corr(), annot = True)
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix', fontsize=15)
    plt.show()

# %%
plotCorrelationMatrix(AS_N, 8)
#Résultat étrange pour la corrélation entre la note imdb et la présence dans le top : 
#corrélation à 0.47 alors que la variable Top IMDB est codé à partir des résultats
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-1a2f90779911> in <module>
# ----> 1 plotCorrelationMatrix(AS_N, 8)
#
# <ipython-input-61-9db2a2364e57> in plotCorrelationMatrix(df, graphWidth)
#       9     corr = sns.heatmap(df.corr(), annot = True)
#      10     plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
# ---> 11     corrMat = plt.matshow(corr, fignum = 1)
#      12     plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
#      13     plt.yticks(range(len(corr.columns)), corr.columns)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in matshow(A, fignum, **kwargs)
#    2297         # Extract actual aspect ratio of array and make appropriately sized
#    2298         # figure.
# -> 2299         fig = figure(fignum, figsize=figaspect(A))
#    2300         ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
#    2301     im = ax.matshow(A, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in figaspect(arg)
#    2864     # Extract the aspect ratio of the array
#    2865     if isarray:
# -> 2866         nr, nc = arg.shape[:2]
#    2867         arr_ratio = nr / nc
#    2868     else:
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('rows' in ['Year released', 'IMDB Rating', 'R Rating', 'Score']) # drop columns with NaN
    df = df.loc[(df!=0).any(axis=1)]
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
plotScatterMatrix (AS_N,10,11)

# %%
AS_N_x_carac = pd.read_csv(r'C:\Users\User\Documents\GitHub\Projet_Python_2A\AS_N_x_carac.csv')

# %%
AS_N_x_carac.tail()
# Out:
#                  Unnamed: 0  Year Released Content Rating  IMDB Rating  \
# 1422  Zumbo's Just Desserts           2016             7+          6.9
# 1423                iZombie           2015            16+          7.9
# 1424              revisions           2019            18+          6.1
# 1425                  天国的嫁衣           2004            NaN          5.6
# 1426                    阳关道           2018            NaN          3.2
#
#       R Rating                         Genre  \
# 1422        60                  Reality,2016
# 1423        82         Drama,Science-Fiction
# 1424        48  Animation,Action & Adventure
# 1425        30                    Drama,2004
# 1426        33                 Comedy,Horror
#
#                                             Description  No of Seasons  \
# 1422  Australia’s very own Willy Wonka Adriano Zumbo...              2
# 1423  A medical student who becomes a zombie joins a...              5
# 1424  An isolated city. An unknown enemy. An uncerta...              1
# 1425  It was with much difficulty that Ai-Ching (Cyn...              1
# 1426  To catch three criminal masterminds, a group o...              1
#
#       Top IMDB Netflix Exclusive  Score
# 1422         0               NaN    NaN
# 1423         0               NaN    NaN
# 1424         0               NaN    NaN
# 1425         0               NaN    NaN
# 1426         0               NaN    NaN

# %%
plotCorrelationMatrix(AS_N_x_carac, 8)
#comme il y a peu de séries qui ont un score, les corrélations sont calculées sur un échantillon plus faible
#d'où des changements dans les valeurs
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-61f74b90b611> in <module>
# ----> 1 plotCorrelationMatrix(AS_N_x_carac, 8)
#       2 #comme il y a peu de séries qui ont un score, les corrélations sont calculées sur un échantillon plus faible
#       3 #d'où des changements dans les valeurs
#
# <ipython-input-61-9db2a2364e57> in plotCorrelationMatrix(df, graphWidth)
#       9     corr = sns.heatmap(df.corr(), annot = True)
#      10     plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
# ---> 11     corrMat = plt.matshow(corr, fignum = 1)
#      12     plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
#      13     plt.yticks(range(len(corr.columns)), corr.columns)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in matshow(A, fignum, **kwargs)
#    2297         # Extract actual aspect ratio of array and make appropriately sized
#    2298         # figure.
# -> 2299         fig = figure(fignum, figsize=figaspect(A))
#    2300         ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
#    2301     im = ax.matshow(A, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in figaspect(arg)
#    2864     # Extract the aspect ratio of the array
#    2865     if isarray:
# -> 2866         nr, nc = arg.shape[:2]
#    2867         arr_ratio = nr / nc
#    2868     else:
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
plotScatterMatrix (AS_N_x_carac,9,10)

# %% [markdown]
# # Représentation des profils de série

# %% [markdown]
# ### (si on a le temps on fait des graphs ou on garde les tableaux ?)

# %%
AS = pd.read_csv(r'C:\Users\User\Documents\GitHub\Projet_Python_2A\AS.csv')
df_carac= pd.read_csv(r'C:\Users\User\Documents\GitHub\Projet_Python_2A\df_carac.csv')

# %%
AS_x_carac = AS.set_index('Series Title').join(df_carac.set_index('Unnamed: 0'))

# %%
AS_Top = AS_x_carac[AS_x_carac["Top IMDB"] == 1]
AS_N_Top = AS_N_x_carac[AS_N_x_carac["Top IMDB"] == 1]

AS_N_score = AS_N_x_carac.dropna('rows' in ['Score'])

N_Originals = AS_N_x_carac[AS_N_x_carac["Netflix Exclusive"] == 'Yes']
N_Originals_Top = N_Originals[N_Originals["Top IMDB"] == 1]

# %% [markdown]
# On s'intéresse aux caractéristiques des séries du Top 250 IMDB

# %%
AS_Top.mean()
#AS_Top.max() Pas forcement très utile
#AS_Top.min()
# Out:
# Unnamed: 0       3145.383798
# Year Released    2008.474104
# IMDB Rating         8.635591
# R Rating           62.994688
# No of Seasons       4.290837
# Top IMDB            1.000000
# Score              29.950000
# dtype: float64

# %% [markdown]
# On s'intéresse aux caractéristiques des séries présentes dans le top quotidien Netflix

# %%
AS_N_score.mean(axis=0)
# Out:
# Year Released    2018.014706
# IMDB Rating         7.213235
# R Rating           72.102941
# No of Seasons       2.132353
# Top IMDB            0.147059
# Score              38.264706
# dtype: float64

# %% [markdown]
# On s'intéresse aux caractéristiques des séries présentes sur Netflix qui entrent dans le Top 250 IMDB

# %%
AS_N_Top.mean()
# Out:
# Year Released    2015.090164
# IMDB Rating         8.631967
# R Rating           70.081967
# No of Seasons       2.303279
# Top IMDB            1.000000
# Score              45.181818
# dtype: float64

# %% [markdown]
# On s'intéresse aux caractéristiques des séries originales Netflix

# %%
N_Originals.mean()
# Out:
# Year Released    2018.865672
# IMDB Rating         7.238806
# R Rating           70.895522
# No of Seasons       1.985075
# Top IMDB            0.134328
# Score              36.388060
# dtype: float64

# %% [markdown]
# On s'intéresse aux caractéristiques des séries originales Netflix qui entrent dans le Top 250 IMDB

# %%
N_Originals_Top.mean()
# Out:
# Year Released    2016.555556
# IMDB Rating         8.566667
# R Rating           82.666667
# No of Seasons       3.666667
# Top IMDB            1.000000
# Score              44.222222
# dtype: float64

# %%
#AS_N_score.groupby(pd.qcut(AS_N_score.Score, 10))['Score'].sum()
#Si on veut "normaliser score on peut diviser la colonne par le 9ème décile"

# %%
#boxplot = AS_N_score.boxplot(column=['IMDB Rating', 'R Rating', 'Score'])
#Pas même échelle donc pas très interéssant, on peut diviser par 10 pour rotten tomatoes 
#par contre c'est tendu pour le score, diviser par le 9ème décile à la limite

# %%
AS_N_x_carac[AS_N_x_carac['Unnamed: 0'].isin(['The Last Dance'])]
# Out:
#           Unnamed: 0  Year Released Content Rating  IMDB Rating  R Rating  \
# 1175  The Last Dance           2020            16+          9.2        90
#
#                       Genre  \
# 1175  Documentary,Biography
#
#                                             Description  No of Seasons  \
# 1175  A 10-part documentary chronicling the untold s...              1
#
#       Top IMDB Netflix Exclusive  Score
# 1175         1                No   98.0

# %%
AS_x_carac.head()
# Out:
#                             Unnamed: 0  Year Released Content Rating  \
#  Mysteries of the Outdoors       12027           2017            NaN
# #BlackLove                        8319           2015            16+
# #MeToo, Now What?                10046           2018            NaN
# #RichKids of Beverly Hills        8233           2014            16+
# #ThatsHarassment                 10699           2018            NaN
#
#                             IMDB Rating  R Rating                Genre  \
#  Mysteries of the Outdoors          NaN        -1  2017,Travel Channel
# #BlackLove                          6.1        37        Reality,Drama
# #MeToo, Now What?                   6.8        27     Documentary,2018
# #RichKids of Beverly Hills          3.1        38         Reality,2014
# #ThatsHarassment                    NaN        18     2018,Prime Video
#
#                                                                   Description  \
#  Mysteries of the Outdoors  Mysteries of the Outdoors has one or more epis...
# #BlackLove                  #BlackLove follows five dynamic black women fr...
# #MeToo, Now What?           Executive editor and host Zainab Salbi goes be...
# #RichKids of Beverly Hills  A look into the privileged lives of several tw...
# #ThatsHarassment            #ThatsHarassment is a series of 6 short films ...
#
#                             No of Seasons                Streaming Platform  \
#  Mysteries of the Outdoors              2                    Travel Channel
# #BlackLove                              2                 Free Services,FYI
# #MeToo, Now What?                       1  Free Services,Prime Video,Hoopla
# #RichKids of Beverly Hills              4                            fuboTV
# #ThatsHarassment                        1            Prime Video,Hulu,Starz
#
#                             Top IMDB Type Netflix Exclusive  Score
#  Mysteries of the Outdoors         0  NaN               NaN    NaN
# #BlackLove                         0  NaN               NaN    NaN
# #MeToo, Now What?                  0  NaN               NaN    NaN
# #RichKids of Beverly Hills         0  NaN               NaN    NaN
# #ThatsHarassment                   0  NaN               NaN    NaN
